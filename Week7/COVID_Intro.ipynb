# %% [markdown]
# ## COVID Impact

# %% [markdown]
# * https://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD

# %% [markdown]
# ![download.png](attachment:6206a96c-d633-45be-8c7f-a965c8fb49b7.png)

# %% [markdown]
# # COVID Radiography Image Classification

# %% [markdown]
# # Data Source (~800M)
#  * https://www.kaggle.com/datasets/tawsifurrahman/covid19-radiography-database

# %% [markdown]
# # Reference Kaggle porjects:
#  * https://www.kaggle.com/code/samuelmathew28/mini-project-yolov8-3-class
#  * https://www.kaggle.com/code/sailikhitarage/covid19-classification
